# %% [markdown]
# **Possible questions which could be answered are:**
# <ul>
#     <li>How does the funding ecosystem change with time?</li>
#     <li>Do cities play a major role in funding?</li>
#     <li>Which industries are favored by investors for funding?</li>
#     <li>Who are the important investors in the Indian Ecosystem?</li>
#     <li>How much funds does startups generally get in India?</li>
#     </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df  = pd.read_csv('../input/indian-startup-funding/startup_funding.csv')
df.head()

# %% [markdown]
# ## This is our data set
# ### Now we are going to see the outline of our dataset

# %%
df.columns

# %%
df.shape

# %%
df.size

# %%
df.isnull().sum()

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False)

# %%
df.info()

# %% [markdown]
# ### Now we are going to do the descriptive analysis of data..

# %%
df.describe().transpose()

# %% [markdown]
# As there is only one column with numerical data , it is showing only description of one column

# %% [markdown]
# In the describe command only "Sr No" has only occured because it has only the int datatype else other has object datatype

# %% [markdown]
# We will go on Analysis of Features one by one each.

# %%
df.columns.tolist()

# %%
df.head(15)

# %%
df.tail()

# %%
df['Remarks'].isnull().sum()

# %%
df.shape

# %% [markdown]
# So, this Remarks Column is not at all important (As contain lots of nan value)

# %%
df['Startup Name'].value_counts()

# %%
 r =df['Startup Name'].unique().tolist()

# %%
len(r)

# %%
df.columns

# %%
df['Amount in USD'].dtype

# %%
df.isnull().any()
